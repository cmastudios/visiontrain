# %% [markdown]
# <a href="https://colab.research.google.com/github/cmastudios/visiontrain/blob/main/L1_Trial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import scipy
import scipy.signal
import matplotlib.pyplot as plt
from PIL import Image
import requests
from io import BytesIO
import ipywidgets
import cv2

# %%
image = Image.open(BytesIO(requests.get("http://public.connor.money.s3.amazonaws.com/TRAIN.JPG").content))
plt.imshow(image)
